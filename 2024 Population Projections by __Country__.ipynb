# %% [markdown]
# 2024 Population Projections by **Country**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read data
df = pd.read_csv('2024Populations.csv')
df
# Out:
#      rank           country TwoLetterID  unMember    pop1980     pop2000  \
# 0       1             India          IN      True  696828385  1059633675
# 1       2             China          CN      True  982372466  1264099069
# 2       3     United States          US      True  223140018   282398554
# 3       4         Indonesia          ID      True  148177096   214072421
# 4       5          Pakistan          PK      True   80624057   154369924
# ..    ...               ...         ...       ...        ...         ...
# 229   230        Montserrat          MS     False      11452        5138
# 230   231  Falkland Islands          FK     False       2240        3080
# 231   232              Niue          NU     False       3637        2074
# 232   233           Tokelau          TK     False       1647        1666
# 233   234      Vatican City          VA      True        733         651
#
#         pop2010     pop2023     pop2024     pop2030     pop2050  landAreaKm  \
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    rank        country TwoLetterID  unMember    pop1980     pop2000  \
# 0     1          India          IN      True  696828385  1059633675
# 1     2          China          CN      True  982372466  1264099069
# 2     3  United States          US      True  223140018   282398554
# 3     4      Indonesia          ID      True  148177096   214072421
# 4     5       Pakistan          PK      True   80624057   154369924
#
#       pop2010     pop2023     pop2024     pop2030     pop2050  landAreaKm  \
# 0  1240613620  1428627663  1441719852  1514994080  1670490596   2973190.0
# 1  1348191368  1425671352  1425178782  1415605906  1312636325   9424702.9
# 2   311182845   339996563   341814420   352162301   375391963   9147420.0
# 3   244016173   277534122   279798049   292150100   317225213   1877519.0
# 4   194454498   240485658   245209815   274029836   367808468    770880.0
#
#    2024YoYChange  2024YoYGrowthRate  2024WorldPercentage  Density_2024
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rank                 234 non-null    int64
#  1   country              234 non-null    object
#  2   TwoLetterID          233 non-null    object
#  3   unMember             234 non-null    bool
#  4   pop1980              234 non-null    int64
#  5   pop2000              234 non-null    int64
#  6   pop2010              234 non-null    int64
#  7   pop2023              234 non-null    int64
#  8   pop2024              234 non-null    int64
#  9   pop2030              234 non-null    int64
#  10  pop2050              234 non-null    int64
#  11  landAreaKm           234 non-null    float64
#  12  2024YoYChange        234 non-null    int64
#  13  2024YoYGrowthRate    234 non-null    float64
#  14  2024WorldPercentage  234 non-null    float64
# ...

# %%
# check for null values
print(df.isnull().sum())
# drop the null row in 3rd column
df = df.dropna(subset=['TwoLetterID'])
# Out:
# rank                   0
# country                0
# TwoLetterID            1
# unMember               0
# pop1980                0
# pop2000                0
# pop2010                0
# pop2023                0
# pop2024                0
# pop2030                0
# pop2050                0
# landAreaKm             0
# 2024YoYChange          0
# 2024YoYGrowthRate      0
# 2024WorldPercentage    0
# Density_2024           0
# dtype: int64

# %%
crltn = df.drop(columns=['country','TwoLetterID'])
sns.heatmap(crltn.corr(), annot=True, cmap='coolwarm', lw=1)
plt.show()

# %%
df
# Out:
#      rank           country TwoLetterID  unMember    pop1980     pop2000  \
# 0       1             India          IN      True  696828385  1059633675
# 1       2             China          CN      True  982372466  1264099069
# 2       3     United States          US      True  223140018   282398554
# 3       4         Indonesia          ID      True  148177096   214072421
# 4       5          Pakistan          PK      True   80624057   154369924
# ..    ...               ...         ...       ...        ...         ...
# 229   230        Montserrat          MS     False      11452        5138
# 230   231  Falkland Islands          FK     False       2240        3080
# 231   232              Niue          NU     False       3637        2074
# 232   233           Tokelau          TK     False       1647        1666
# 233   234      Vatican City          VA      True        733         651
#
#         pop2010     pop2023     pop2024     pop2030     pop2050  landAreaKm  \
# ...

# %% [markdown]
# plot ten most populated countries

# %%
# most populated nations

top10 = df.loc[df['pop2024'].nlargest(10).index]
top1980 = df.loc[df['pop1980'].nlargest(10).index]

sns.barplot(x=top10['country'], y=top10['pop2024'], hue=top10['unMember'])
plt.title('Top 10 Most Populated Countries 2024')

plt.xticks(rotation=90)
plt.show()
top10
# Out:
#    rank        country TwoLetterID  unMember    pop1980     pop2000  \
# 0     1          India          IN      True  696828385  1059633675
# 1     2          China          CN      True  982372466  1264099069
# 2     3  United States          US      True  223140018   282398554
# 3     4      Indonesia          ID      True  148177096   214072421
# 4     5       Pakistan          PK      True   80624057   154369924
# 5     6        Nigeria          NG      True   72951439   122851984
# 6     7         Brazil          BR      True  122288383   175873720
# 7     8     Bangladesh          BD      True   83929765   129193327
# 8     9         Russia          RU      True  138257420   146844839
# 9    10       Ethiopia          ET      True   34945469    67031867
#
#       pop2010     pop2023     pop2024     pop2030     pop2050  landAreaKm  \
# 0  1240613620  1428627663  1441719852  1514994080  1670490596   2973190.0
# ...

# %% [markdown]
# india population growth over the years

# %%
# india population growth over the years
ind_data = df[df['country']== 'India']
nind_data = ind_data.iloc[:,4:11]
print('nind_data')

# plot barchart
plt.figure(figsize=(10, 6))
sns.barplot(x=nind_data.columns, y=nind_data.iloc[0])
plt.title('India Population Growth Over the Years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()
# Out:
# nind_data

# %% [markdown]
# plot population density

# %%
sns.scatterplot(x=df['landAreaKm'], y=df['Density_2024'], hue=df['unMember'])
plt.show()

# %% [markdown]
# population change from 2023 to 2024

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,6))
sns.barplot(data=top10, x='country', y="2024YoYChange")
plt.title('Top 10 Countries by Population Change from 2023 to 2024')
plt.xlabel('Population Change')
plt.ylabel('Country')
plt.show()
